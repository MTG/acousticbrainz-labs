# %%
import numpy as np
import pandas as pd
import graphs

# %%
graphs.init_setup()

# %%
features = pd.read_csv('ab-2017-01-23-lowlevel-features.csv', low_memory=False)

# %%
key = features['key_key'].dropna()
scale = features['key_scale'].dropna()

# %%
key_counts = pd.Series.value_counts(list(zip(scale, key))).sort_index()
keys = tuple(zip(*key_counts.keys()))

# %%
graphs.key_est_bar(keys, key_counts)
