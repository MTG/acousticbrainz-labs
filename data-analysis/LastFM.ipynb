# %%
import numpy as np
import pandas as pd
import graphs
import genre_mapping
import json

# %%
graphs.init_setup()

# %%
features = pd.read_csv('ab-2017-01-23-loudness-features.csv')

# %%
with open('lastfm-genre-mapping-2016-03-02.json')as f:
    data = json.load(f)

# %%
avg_loudness = features['average_loudness']
f_mbids = features['recording_mbid']
l_dict = dict(zip(f_mbids, avg_loudness))

# %%
graphs.features_gen_box(data, l_dict, 'genre_lastfm')
